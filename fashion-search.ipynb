# %%
from io import BytesIO
import faiss
import numpy as np
import torch
import torchvision.transforms as T
from PIL import Image
import cv2
import json
from tqdm.notebook import tqdm
from matplotlib import pyplot as plt
import supervision as sv
import csv
import requests

device = 'cpu'
torch.set_default_device(device)

# %%
dinov2_vits14 = torch.hub.load("facebookresearch/dinov2", "dinov2_vits14")
# Out:
# Using cache found in /Users/saumi/.cache/torch/hub/facebookresearch_dinov2_main
# /Users/saumi/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /Users/saumi/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /Users/saumi/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")

# %%
transform_image = T.Compose([T.ToTensor(), T.Resize(244), T.CenterCrop(224), T.Normalize([0.5], [0.5])])

def load_image(url: str) -> torch.Tensor:
    """
    Load an image from a URL and return a tensor that can be used as an input to DINOv2.
    """
    # Download the image from the URL
    response = requests.get(url)

    if response.status_code != 200:
        raise Exception(f'Failed to download image from {url}')

    # Open the image from the downloaded content
    img = Image.open(BytesIO(response.content))

    # Assuming transform_image is a function that applies necessary transformations
    transformed_img = transform_image(img)[:3].unsqueeze(0)

    return transformed_img

# %%
def create_index(files: list) -> faiss.IndexFlatL2:
    """
    Create an index that contains all of the images in the specified list of files.
    """
    index = faiss.IndexFlatL2(384)

    all_embeddings = {}
    
    with torch.no_grad():
      for name, images in tqdm(files):
        tqdm.write(f'[INFO] - Processing {name}')
        all_embeddings[name] = []
        for file in images:
            embeddings = dinov2_vits14(load_image(file).to(device))
            tqdm.write('[INFO] - Generated embeddings')
            embedding = embeddings[0].cpu().numpy()
            tqdm.write('[INFO] - Converted embeddings to numpy')
            all_embeddings[name].append(np.array(embedding).reshape(1, -1).tolist())
            tqdm.write('[INFO] - Transformed embeddings to list')
            index.add(np.array(embedding).reshape(1, -1))
            tqdm.write('[INFO] - Added to index')

    with open("all_embeddings.json", "w") as f:
        f.write(json.dumps(all_embeddings))

    faiss.write_index(index, "data.bin")

    return index, all_embeddings

# %%
def extract_image_urls(csv_file):
    images_metadata = []  # Dictionary to store image URLs for each item

    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        next(reader)  # Skip header

        for row in reader:
            name, _, *image_urls = row
            images_metadata.append((name, image_urls))

    return images_metadata

# %%
files = extract_image_urls('items.csv')[:100]

data_index, all_embeddings = create_index(files)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Chico Easy Wear brand new, no tags
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing One of a kind garnet necklace
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Swees For Fitbit Alta HR and Alta Band Metal Small & Large Wristband
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Nike Men's Crater Impact Shoes | Shoe Size 9.5 / 10 | Green/Grey/White
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing New Womens Leather Gloves Brown
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing small adidas duffle bag
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Coach Backpack
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing VINTAGE Steve madden Lynn suede stacked heel pointy booties Size 6.5
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing CARTIER CT0286O GLASSES
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Marvel hat
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Disneys Dr Strange 2 backpack new with tags
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing JOVANI Red Fitted Strapless Lace Dress
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Beautiful Wedding Gown
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Sam Edelman FLORENCE BALLET FLAT (BLACK)
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Rebecca Minkoff Handbag
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# ...
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing white string of white star white italian lights
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing white string of white star white italian lights
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing COLE HAAN Men's Tucker Venetian Loafer | French Roast | Size 9M | NEW
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing BOTTEGA VENETA Sunglasses. New in Original box Movie Star Glasses
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Kaopabolo Men/Women Tennis Walking Running Athletic Shoes 9.5 M | 11 W
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Victoria Secret Track Team Xl Bag -
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Vintage motorcycle jacket
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing 2007 Archive Vans Size 43 (US 10-10.5)
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Geobaskets/Dunks Size 44 (US 11)
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Issey Miyake AW96 MA-1 Parachute Cargo Bomber Jacket Size Large
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Prada leather boots with decorative grommets.
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing Tony Lama Men's Lizard Boots,  Size 10 B,  Mint Condition
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Processing D&Y Mens Wool hat with flaps (NEW)
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index
# [INFO] - Generated embeddings
# [INFO] - Converted embeddings to numpy
# [INFO] - Transformed embeddings to list
# [INFO] - Added to index

# %%
def search_index(index: faiss.IndexFlatL2, embeddings: list, k: int = 3) -> list:
    """
    Search the index for the images that are most similar to the provided image.
    """
    D, I = index.search(np.array(embeddings[0].reshape(1, -1)), k)

    return I[0]

# %%
def get_from_files(index: int):
    for name, images in files:
        index -= len(images)
        if index <= 0:
            return name, images[0]
    raise Exception('Index out of range')

# %%
with torch.no_grad():
    embedding = dinov2_vits14(load_image('https://images.craigslist.org/00z0z_1ZngK1zVYsp_0CI0t2_600x450.jpg').to(device))

    indices = search_index(data_index, np.array(embedding[0].cpu()).reshape(1, -1))

    for i, index in enumerate(indices):
        print()
        print(f"Image {i}: {get_from_files(index)}")
# Out:
# Image 0: ('BRIDAL GOWN', 'https://images.craigslist.org/00B0B_1EBDmCJH4nY_0mY0uD_600x450.jpg')
#
# Image 1: ('Beautiful Wedding Gown', 'https://images.craigslist.org/00808_irnTTMHRhBMz_0hq0r6_600x450.jpg')
#
# Image 2: ('JOVANI Red Fitted Strapless Lace Dress', 'https://images.craigslist.org/00m0m_iWM3HS5mYKE_600x450.jpg')
